# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col ='ResponseId')
schema_df =pd.read_csv('data/survey_results_schema.csv',index_col='qname')

# %%
df.head()
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 1           I agree                   None of these  18-24 years old
# 2           I agree  I am a developer by profession  25-34 years old
# 3           I agree  I am a developer by profession  45-54 years old
# 4           I agree  I am a developer by profession  25-34 years old
# 5           I agree  I am a developer by profession  25-34 years old
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# 2                                         Employed, full-time
# 3                                         Employed, full-time
# 4                                         Employed, full-time
# 5           Employed, full-time;Independent contractor, fr...
#
#                                       RemoteWork  \
# ResponseId
# 1                                            NaN
# ...

# %%
#filt = (df['Country'] == 'India').value_counts()
filt= (df['Country'] == 'India')
India_df = df.loc[filt]
India_df
# Out:
#                Q120                                         MainBranch  \
# ResponseId
# 10          I agree                     I am a developer by profession
# 67          I agree                     I am a developer by profession
# 79          I agree                     I am a developer by profession
# 83          I agree                     I am a developer by profession
# 86          I agree                     I am a developer by profession
# ...             ...                                                ...
# 89120       I agree                     I am a developer by profession
# 89122       I agree  I am not primarily a developer, but I write co...
# 89165       I agree                     I am a developer by profession
# 89166       I agree                     I am a developer by profession
# 89168       I agree                     I am a developer by profession
#
#                         Age                              Employment  \
# ResponseId
# ...

# %%
India_df.to_csv('Data/modified.csv')

# %%
#CUSTOM SEPERATOR
India_df.to_csv('Data/modified.tsv', sep = '\t')

# %%
#to write to an excel file
# pip install xlwt
#to read an excel file, pip install xlrd

# %%
India_df.to_excel('Data/modified.xlsx')
#to read or write to a sheet in excel

# %%
#to JSON
India_df.to_json('Data/modified.json')

# %%
#to change it to list like
India_df.to_json('Data/modified.json', orient= 'records', lines= True)

# %%
#Write to SQL
#allows to work easily with databases. Object relational mapper that uses python to interact with databases.
from sqlalchemy import create_engine
import psycopg2

# %%
engine = create_engine('postgresql://dbuseer:dbpass@localhost:8888/sample_db')

# %%
#India_df.to_sql('sample_tabel', engine, if_exists ='replace')

# %%
#to read only specific column
#sql_df = pd.read_sql_query('SELECT * FROM sample_table', engine, index_col ='Respondent')

# %%
#sql_df.head()

# %%
#to load in data from a url
#posts_df = pd.read_json('URL')
